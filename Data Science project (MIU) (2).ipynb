# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
import pandas as pd
import numpy as np


 
'''
This data contains Mathematical performance for PISA
Mathematical performance, for PISA, measures the mathematical literacy of a 15 year-old to formulate,
employ and interpret mathematics in a variety of contexts to describe, predict and explain phenomena,
recognising the role that mathematics plays in the world. The mean score is the measure. 
A mathematically literate student recognises the role that mathematics plays in the world in order 
to make well-founded judgments and decisions needed by constructive, engaged and reflective citizens.'''

# reading files for
df1 = pd.read_csv('C:\\Users\SEGUN\\Downloads\\DP_LIVE_21102020074438999.csv')


# cleaning the data file
df1.set_index(df1['LOCATION'], inplace = True)


# restrict the data to only Australia and split separate the sex
df_boy = df1[(df1['SUBJECT']=='BOY') & (df1['LOCATION']=='AUS')]
df_girl = df1[(df1['SUBJECT']=='GIRL') & (df1['LOCATION']=='AUS')]

# drop the unwanted columns
df_boy.drop(['SUBJECT', 'INDICATOR', 'MEASURE', 'LOCATION', 'Flag Codes','FREQUENCY'], axis =1, inplace = True)
df_girl.drop(['SUBJECT', 'INDICATOR', 'MEASURE', 'LOCATION',  'Flag Codes','FREQUENCY'], axis =1, inplace = True)


# I want to compare the Maths perfomance level of girls and boys in australia between the year...


df_both=pd.merge(df_boy,df_girl, how = 'inner', on = ['TIME'])

# Position of bars on x-axis
ind = np.arange(6)

plt.figure()
plt.plot(df_both['TIME'],df_both['Value_x'], label = 'boys');
plt.plot(df_both['TIME'],df_both['Value_y'], label = 'girls');
plt.grid(True)
plt.legend()
plt.xticks(df_both['TIME'] + width / 2, tuple(df_both['TIME']))
plt.xlabel('Years')
plt.ylabel('mean of perfomance value')
plt.title('Maths perfomance PISA for girls and boys at age 15 in Australia\n in 3 years intervals from 2003 - 2018 ')

# Finding the best position for legends and putting it
plt.legend(loc='best')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
